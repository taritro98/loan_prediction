# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

os.chdir('C:/Users/TARITRO GHOSHAL/Desktop/datasets')

df=pd.read_csv('loan-prediction.csv')

# %%
df.head(40)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
print(df.shape,df.info(),df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB
# (614, 13) None        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# ...

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
df['Gender']=df['Gender'].map({'Male':0,'Female':1})

# %%
df.head()
# Out:
#    Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     0.0      No          0      Graduate            No             5849
# 1     0.0     Yes          1      Graduate            No             4583
# 2     0.0     Yes          0      Graduate           Yes             3000
# 3     0.0     Yes          0  Not Graduate            No             2583
# 4     0.0      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
df['Married']=df['Married'].map({'No':0,'Yes':1})
df['Education']=df['Education'].map({'Not Graduate':0,'Graduate':1})
df['Self_Employed']=df['Self_Employed'].map({'No':0,'Yes':1})
df['Property_Area']=df['Property_Area'].map({'Rural':0,'Semiurban':1,'Urban':2})
df['Loan_Status']=df['Loan_Status'].map({'N':0,'Y':1})

# %%
df.head(40)
# Out:
#     Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0      0.0      0.0          0          1            0.0             5849
# 1      0.0      1.0          1          1            0.0             4583
# 2      0.0      1.0          0          1            1.0             3000
# 3      0.0      1.0          0          0            0.0             2583
# 4      0.0      0.0          0          1            0.0             6000
# 5      0.0      1.0          2          1            1.0             5417
# 6      0.0      1.0          0          0            0.0             2333
# 7      0.0      1.0         3+          1            0.0             3036
# 8      0.0      1.0          2          1            0.0             4006
# 9      0.0      1.0          1          1            0.0            12841
# 10     0.0      1.0          2          1            0.0             3200
# 11     0.0      1.0          2          1            NaN             2500
# ...

# %%
df['Self_Employed'].fillna(method='ffill',inplace=True)

# %%
df['Gender'].fillna(method='ffill',inplace=True)
df['Married'].fillna(method='ffill',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
# Gender               614 non-null float64
# Married              614 non-null float64
# Dependents           599 non-null object
# Education            614 non-null int64
# Self_Employed        614 non-null float64
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null int64
# Loan_Status          614 non-null int64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 57.6+ KB

# %%
df['Dependents'].replace('3+',3,inplace=True)
df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0      0.0          0          1            0.0             5849
# 1       0.0      1.0          1          1            0.0             4583
# 2       0.0      1.0          0          1            1.0             3000
# 3       0.0      1.0          0          0            0.0             2583
# 4       0.0      0.0          0          1            0.0             6000
# 5       0.0      1.0          2          1            1.0             5417
# 6       0.0      1.0          0          0            0.0             2333
# 7       0.0      1.0          3          1            0.0             3036
# 8       0.0      1.0          2          1            0.0             4006
# 9       0.0      1.0          1          1            0.0            12841
# 10      0.0      1.0          2          1            0.0             3200
# ...

# %%
df['Dependents'].fillna(df['Dependents'].median(),inplace=True)

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(),inplace=True)

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median(),inplace=True)

# %%
df['Credit_History'].fillna(method='ffill',inplace=True)

# %%
df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0      0.0          0          1            0.0             5849
# 1       0.0      1.0          1          1            0.0             4583
# 2       0.0      1.0          0          1            1.0             3000
# 3       0.0      1.0          0          0            0.0             2583
# 4       0.0      0.0          0          1            0.0             6000
# 5       0.0      1.0          2          1            1.0             5417
# 6       0.0      1.0          0          0            0.0             2333
# 7       0.0      1.0          3          1            0.0             3036
# 8       0.0      1.0          2          1            0.0             4006
# 9       0.0      1.0          1          1            0.0            12841
# 10      0.0      1.0          2          1            0.0             3200
# ...

# %%
import seaborn as sns

facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'Loan_Amount_Term',shade= True)
facet.set(xlim=(0, df['Loan_Amount_Term'].max()))
facet.add_legend()
 
plt.show()

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 342.0     14
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
#Binning
df.loc[(df['Loan_Amount_Term'] >= 0) & (df['Loan_Amount_Term'] <= 120), 'Loan_Amount_Term'] = 1,
df.loc[(df['Loan_Amount_Term'] > 120) & (df['Loan_Amount_Term'] <= 240), 'Loan_Amount_Term'] = 2,
df.loc[(df['Loan_Amount_Term'] > 240) & (df['Loan_Amount_Term'] <= 360), 'Loan_Amount_Term'] = 3,
df.loc[ df['Loan_Amount_Term'] > 360, 'Loan_Amount_Term'] = 4

# %%
df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0      0.0          0          1            0.0             5849
# 1       0.0      1.0          1          1            0.0             4583
# 2       0.0      1.0          0          1            1.0             3000
# 3       0.0      1.0          0          0            0.0             2583
# 4       0.0      0.0          0          1            0.0             6000
# 5       0.0      1.0          2          1            1.0             5417
# 6       0.0      1.0          0          0            0.0             2333
# 7       0.0      1.0          3          1            0.0             3036
# 8       0.0      1.0          2          1            0.0             4006
# 9       0.0      1.0          1          1            0.0            12841
# 10      0.0      1.0          2          1            0.0             3200
# ...

# %%
df['ApplicantIncome'].value_counts()
def pie_chart(feature):
    loan_give = df[df['Loan_Status']==1][feature].value_counts()
    loan_not_give = df[df['Loan_Status']==0][feature].value_counts()
    df1 = pd.DataFrame([loan_give,loan_not_give])
    df1.index = ['Loan_1','Loan_0']
    df1.plot(kind='pie', subplots=True, figsize=(10,5))
    df1.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.xlim(2000,4000)
# Out:
# (2000, 4000)

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.xlim(4000,6000)
# Out:
# (4000, 6000)

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.xlim(6000,8000)
# Out:
# (6000, 8000)

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'ApplicantIncome',shade= True)
facet.set(xlim=(0, df['ApplicantIncome'].max()))
facet.add_legend()
plt.xlim(8000,10000)
# Out:
# (8000, 10000)

# %%
df.loc[(df['ApplicantIncome'] >= 0) & (df['ApplicantIncome'] <= 2000), 'ApplicantIncome'] = 0,
df.loc[(df['ApplicantIncome'] > 2000) & (df['ApplicantIncome'] <= 4000), 'ApplicantIncome'] =1,
df.loc[(df['ApplicantIncome'] > 4000) & (df['ApplicantIncome'] <= 6000), 'ApplicantIncome'] =2,
df.loc[(df['ApplicantIncome'] > 6000) & (df['ApplicantIncome'] <= 8000), 'ApplicantIncome'] =3,
df.loc[(df['ApplicantIncome'] > 8000), 'ApplicantIncome'] =4

# %%
df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0      0.0          0          1            0.0                2
# 1       0.0      1.0          1          1            0.0                2
# 2       0.0      1.0          0          1            1.0                1
# 3       0.0      1.0          0          0            0.0                1
# 4       0.0      0.0          0          1            0.0                2
# 5       0.0      1.0          2          1            1.0                2
# 6       0.0      1.0          0          0            0.0                1
# 7       0.0      1.0          3          1            0.0                1
# 8       0.0      1.0          2          1            0.0                2
# 9       0.0      1.0          1          1            0.0                4
# 10      0.0      1.0          2          1            0.0                1
# ...

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'CoapplicantIncome',shade= True)
facet.set(xlim=(0, df['CoapplicantIncome'].max()))
facet.add_legend()
plt.show()

# %%
df.loc[(df['CoapplicantIncome'] >= 0) & (df['CoapplicantIncome'] <= 2000), 'CoapplicantIncome'] = 0,
df.loc[(df['CoapplicantIncome'] > 2000) & (df['CoapplicantIncome'] <= 4000), 'CoapplicantIncome'] =1,
df.loc[(df['CoapplicantIncome'] > 4000) & (df['CoapplicantIncome'] <= 6000), 'CoapplicantIncome'] =2,
df.loc[(df['CoapplicantIncome'] > 6000) & (df['CoapplicantIncome'] <= 8000), 'CoapplicantIncome'] =3,
df.loc[(df['CoapplicantIncome'] > 8000), 'CoapplicantIncome'] =4

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0      0.0      0.0          0          1            0.0                2
# 1      0.0      1.0          1          1            0.0                2
# 2      0.0      1.0          0          1            1.0                1
# 3      0.0      1.0          0          0            0.0                1
# 4      0.0      0.0          0          1            0.0                2
# 5      0.0      1.0          2          1            1.0                2
# 6      0.0      1.0          0          0            0.0                1
# 7      0.0      1.0          3          1            0.0                1
# 8      0.0      1.0          2          1            0.0                2
# 9      0.0      1.0          1          1            0.0                4
# 10     0.0      1.0          2          1            0.0                1
# 11     0.0      1.0          2          1            0.0                1
# ...

# %%
facet = sns.FacetGrid(df, hue="Loan_Status",aspect=4)
facet.map(sns.kdeplot,'LoanAmount',shade= True)
facet.set(xlim=(0, df['LoanAmount'].max()))
facet.add_legend()
plt.show()

# %%
df.loc[(df['LoanAmount'] >= 0) & (df['LoanAmount'] <= 50), 'LoanAmount'] = 0,
df.loc[(df['LoanAmount'] > 50) & (df['LoanAmount'] <= 100), 'LoanAmount'] =1,
df.loc[(df['LoanAmount'] > 100) & (df['LoanAmount'] <= 150), 'LoanAmount'] =2,
df.loc[(df['LoanAmount'] > 150) & (df['LoanAmount'] <= 200), 'LoanAmount'] =3,
df.loc[(df['LoanAmount'] > 200) & (df['LoanAmount'] <= 250), 'LoanAmount'] =4,
df.loc[(df['LoanAmount'] > 250), 'LoanAmount'] =4

# %%
df.head(30)
# Out:
#     Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0      0.0      0.0          0          1            0.0                2
# 1      0.0      1.0          1          1            0.0                2
# 2      0.0      1.0          0          1            1.0                1
# 3      0.0      1.0          0          0            0.0                1
# 4      0.0      0.0          0          1            0.0                2
# 5      0.0      1.0          2          1            1.0                2
# 6      0.0      1.0          0          0            0.0                1
# 7      0.0      1.0          3          1            0.0                1
# 8      0.0      1.0          2          1            0.0                2
# 9      0.0      1.0          1          1            0.0                4
# 10     0.0      1.0          2          1            0.0                1
# 11     0.0      1.0          2          1            0.0                1
# ...

# %%
#Model
from sklearn.model_selection import train_test_split

train,test=train_test_split(df,test_size=0.2)

# %%
print(train.info(),test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 419 to 226
# Data columns (total 12 columns):
# Gender               491 non-null float64
# Married              491 non-null float64
# Dependents           491 non-null object
# Education            491 non-null int64
# Self_Employed        491 non-null float64
# ApplicantIncome      491 non-null int64
# CoapplicantIncome    491 non-null float64
# LoanAmount           491 non-null float64
# Loan_Amount_Term     491 non-null float64
# Credit_History       491 non-null float64
# Property_Area        491 non-null int64
# Loan_Status          491 non-null int64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 49.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123 entries, 117 to 256
# Data columns (total 12 columns):
# Gender               123 non-null float64
# Married              123 non-null float64
# Dependents           123 non-null object
# Education            123 non-null int64
# ...

# %%
target=test['Loan_Status']
target
# Out:
# 117    1
# 436    1
# 487    0
# 400    0
# 166    0
# 13     0
# 569    0
# 122    1
# 349    1
# 336    1
# 214    1
# 203    1
# 292    1
# 276    1
# 151    1
# 447    0
# 484    1
# 2      1
# 44     1
# 167    1
# 582    1
# 42     1
# 286    0
# 516    1
# 376    1
# 14     1
# 131    1
# 327    1
# 543    1
# 206    1
#       ..
# 120    1
# 224    1
# 138    0
# 540    1
# 133    1
# 70     1
# 309    1
# 383    1
# 233    1
# 442    1
# 369    0
# 494    0
# 527    1
# 328    0
# 31     0
# 170    1
# 511    1
# 180    0
# 284    0
# 390    1
# 492    1
# 267    1
# 192    0
# 464    0
# 473    1
# 17     0
# 347    1
# 105    1
# 330    1
# 256    0
# Name: Loan_Status, Length: 123, dtype: int64

# %%
test.drop('Loan_Status',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-bac5a604bf47> in <module>
# ----> 1 test.drop('Loan_Status',axis=1,inplace=True)
#       2 test
#
# c:\users\taritro ghoshal\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\taritro ghoshal\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import numpy as np

# %%
#Cross Validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
train_target=train['Loan_Status']
train.drop('Loan_Status',axis=1,inplace=True)

# %%
#KNN
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train,train_target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.71428571 0.73469388 0.71428571 0.71428571 0.63265306
#  0.65306122 0.75510204 0.79591837 0.71428571]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 72.29

# %%
#Decision Tree
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train,train_target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.72       0.75510204 0.73469388 0.63265306 0.67346939 0.67346939
#  0.63265306 0.73469388 0.79591837 0.73469388]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 70.87

# %%
#Random Forest
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train, train_target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84       0.79591837 0.69387755 0.71428571 0.81632653 0.73469388
#  0.67346939 0.7755102  0.79591837 0.73469388]

# %%
round(np.mean(score)*100, 2)
# Out:
# 75.75

# %%
#Naive Bayes
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train, train_target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82       0.83673469 0.81632653 0.81632653 0.81632653 0.75510204
#  0.71428571 0.85714286 0.81632653 0.79591837]

# %%
round(np.mean(score)*100, 2)
# Out:
# 80.44

# %%
#SVM
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train, train_target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84       0.81632653 0.83673469 0.81632653 0.81632653 0.73469388
#  0.75510204 0.79591837 0.83673469 0.79591837]
# c:\users\taritro ghoshal\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# c:\users\taritro ghoshal\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
round(np.mean(score)*100,2)
# Out:
# 80.44

# %%
#Testing

clf = GaussianNB()
clf.fit(train,train_target)

prediction = clf.predict(test)

# %%
train.head()
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 419     0.0      1.0          0          1            0.0                1
# 22      0.0      1.0          0          0            0.0                1
# 134     0.0      0.0          0          1            0.0                2
# 568     1.0      0.0          0          1            0.0                1
# 594     0.0      1.0          0          1            1.0                4
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 419                0.0         2.0               3.0             1.0
# 22                 0.0         2.0               3.0             0.0
# 134                0.0         2.0               3.0             1.0
# 568                0.0         0.0               3.0             1.0
# 594                0.0         4.0               3.0             1.0
#
#      Property_Area
# 419              1
# 22               1
# 134              1
# ...

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, test,target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.53846154 0.84615385 0.92307692 0.83333333 0.75       0.91666667
#  0.75       0.66666667 0.58333333 0.83333333]

# %%
round(np.mean(score)*100,2)
# Out:
# 76.41
